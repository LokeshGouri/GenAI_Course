# %% [markdown]
# <a href="https://colab.research.google.com/github/LokeshGouri/GenAI_Course/blob/main/Pythin_using_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
print(pandas.__version__)
# Out:
# 2.0.3

# %%
myDict = {
    "cars" : ["BMW", "TOYOTA", "MARUTI"],
    "count" : [1,4,7]
}

# %%
carsDF = pd.DataFrame(myDict)

# %%
carsDF.head()
# Out:
#      cars  count
# 0     BMW      1
# 1  TOYOTA      4
# 2  MARUTI      7

# %%
carsDF.tail()
# Out:
#      cars  count
# 0     BMW      1
# 1  TOYOTA      4
# 2  MARUTI      7

# %%
a = [1,3,4]
pdSeries = pd.Series(a)
print(pdSeries)
# Out:
# 0    1
# 1    3
# 2    4
# dtype: int64

# %%
type(pdSeries)
# Out:
# pandas.core.series.Series

# %%
pdCarSeries = pd.Series(carsDF.cars)
print(pdCarSeries)
# Out:
# 0       BMW
# 1    TOYOTA
# 2    MARUTI
# Name: cars, dtype: object

# %%
pdCarSeries = pd.Series(carsDF.cars, index=["x","y","z"])
print(pdCarSeries)
# Out:
# x    NaN
# y    NaN
# z    NaN
# Name: cars, dtype: object

# %%
pdCarSeries = pd.Series(carsDF.cars.values, index=["x","y","z"])
print(pdCarSeries)
# Out:
# x       BMW
# y    TOYOTA
# z    MARUTI
# dtype: object

# %%
pdCarSeries.reset_index()
# Out:
#   index       0
# 0     x     BMW
# 1     y  TOYOTA
# 2     z  MARUTI

# %%
pdCarSeries.reindex()
# Out:
# x       BMW
# y    TOYOTA
# z    MARUTI
# dtype: object

# %%
myDictSeries = pd.Series(myDict)
print(myDictSeries)
# Out:
# cars     [BMW, TOYOTA, MARUTI]
# count                [1, 4, 7]
# dtype: object

# %%
carsDF.shape
# Out:
# (3, 2)

# %%
carsDF.columns
# Out:
# Index(['cars', 'count'], dtype='object')

# %%
carsDF.loc[0]
# Out:
# cars     BMW
# count      1
# Name: 0, dtype: object

# %%
carsDF.loc[0:2]
# Out:
#      cars  count
# 0     BMW      1
# 1  TOYOTA      4
# 2  MARUTI      7

# %%
carsDF.loc[:1]
# Out:
#      cars  count
# 0     BMW      1
# 1  TOYOTA      4

# %%
emptyDF = pd.DataFrame(columns=["A","B"])
print(emptyDF)
# Out:
# Empty DataFrame
# Columns: [A, B]
# Index: []

# %%
df = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
dfJson = pd.read_json("/content/sample_data/anscombe.json")
dfJson.head()
# Out:
#   Series   X     Y
# 0      I  10  8.04
# 1      I   8  6.95
# 2      I  13  7.58
# 3      I   9  8.81
# 4      I  11  8.33

# %%
dfJson.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Series  44 non-null     object
#  1   X       44 non-null     int64
#  2   Y       44 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.2+ KB

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...
